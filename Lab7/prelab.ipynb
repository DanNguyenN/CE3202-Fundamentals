# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from scipy.interpolate import interp1d

# %%
#Part 1a
df17k = pd.read_csv(".\prelab\OpDifference.csv", encoding="latin1", skiprows=28)
df17k.columns = ['time', "input", "output"]

df17k["input2"] = df17k["input"] * -1

df17k = df17k[(df17k['time'] < 5/17000)]



#Draw a horizontal line at 0 with transparency
plt.axhline(y=0, color='k', alpha=.2)

plt.plot(df17k['time'] * 1000, df17k['input'], label="Input")
plt.plot(df17k['time'] * 1000, df17k['input2'], label="Input", c='k')
plt.plot(df17k['time'] * 1000, df17k['output'], label="Output", c="r")
plt.xlabel("Time (ms)")
plt.yticks([-2,-.1,.1,2])



plt.ylabel("Voltage (V)")
plt.title("PSpice Simulated - Difference OpAmp Amplifier with 17kHz Input")

plt.grid()

# %%
df500 = pd.read_csv(".\prelab\differential\sine\differential500.csv", skiprows=19, encoding="latin1")
df500.columns = ["time", "outputV", "inputV"]
df1k = pd.read_csv(".\prelab\differential\sine\differential1k.csv", skiprows=19, encoding="latin1")
df1k.columns = ["time", "outputV", "inputV"]
df5k = pd.read_csv(".\prelab\differential\sine\differential5k.csv", skiprows=19, encoding="latin1")
df5k.columns = ["time", "outputV", "inputV"]
df10k = pd.read_csv(".\prelab\differential\sine\differential10k.csv", skiprows=19, encoding="latin1")
df10k.columns = ["time", "outputV", "inputV"]

differentialSineDataset = [df500, df1k, df5k, df10k]

#Plot all df in differentialSineDataset
#Get the point where the input is 0 and greater than -0015
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
df500 = df500[(df500["time"] < 3/500 )]
plt.plot(df500["time"] * 1000, df500["inputV"] * 1000, label="input")
plt.plot(df500["time"] * 1000, df500["outputV"] * 1000, label="output", c="r")

plt.xlabel("Time (ms)")
plt.ylabel("Voltage (mV)")
plt.title("PSpice Simulated - Differential Amplifier, Sine Wave Input 500Hz")
plt.grid()

plt.subplot(2,2,2)
df1k = df1k[(df1k["time"] < 3/1000 )]
plt.plot(df1k["time"] * 1000, df1k["inputV"]* 1000, label="input")
plt.plot(df1k["time"] * 1000, df1k["outputV"]* 1000, label="output", c="r")

plt.xlabel("Time (ms)")
plt.ylabel("Voltage (mV)")
plt.title("PSpice Simulated - Differential Amplifier, Sine Wave Input 1kHz")
plt.grid()

plt.subplot(2,2,3)
df5k = df5k[(df5k["time"] < 3/5000 )]
plt.plot(df5k["time"] * 1000, df5k["inputV"]* 1000, label="input")
plt.plot(df5k["time"] * 1000, df5k["outputV"]* 1000, label="output", c="r")

plt.xlabel("Time (ms)")
plt.ylabel("Voltage (mV)")
plt.title("PSpice Simulated - Differential Amplifier, Sine Wave Input 5kHz")
plt.grid()

plt.subplot(2,2,4)
df10k = df10k[(df10k["time"] < 3/10000 )]
plt.plot(df10k["time"] * 1000, df10k["inputV"]* 1000, label="input")
plt.plot(df10k["time"] * 1000, df10k["outputV"]* 1000, label="output", c="r")

plt.xlabel("Time (ms)")
plt.ylabel("Voltage (mV)")
plt.title("PSpice Simulated - Differential Amplifier, Sine Wave Input 10kHz")
plt.grid()

# %%
df500 = pd.read_csv(".\prelab\differential\\triangle\differentialTriangle500.csv", skiprows=19, encoding="latin1")
df500.columns = ["time", "inputV", "outputV"]
df1k = pd.read_csv(".\prelab\differential\\triangle\differentialTriangle1k.csv", skiprows=19, encoding="latin1")
df1k.columns = ["time", "outputV", "inputV"]
df5k = pd.read_csv(".\prelab\differential\\triangle\differentialTriangle5k.csv", skiprows=19, encoding="latin1")
df5k.columns = ["time", "inputV", "outputV"]
df10k = pd.read_csv(".\prelab\differential\\triangle\differentialTriangle10k.csv", skiprows=19, encoding="latin1")
df10k.columns = ["time", "inputV", "outputV"]

differentialSineDataset = [df500, df1k, df5k, df10k]

#Plot all df in differentialSineDataset
#Get the point where the input is 0 and greater than -0015
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
df500 = df500[(df500["time"] < 3/500 )]
plt.plot(df500["time"] * 1000, df500["inputV"], label="input")
plt.plot(df500["time"] * 1000, df500["outputV"], label="output", c="r")

plt.xlabel("Time (ms)")
plt.ylabel("Voltage (V)")
plt.title("PSpice Simulated - Differential Amplifier, Triangle Wave Input 500Hz")
plt.grid()

plt.subplot(2,2,2)
df1k = df1k[(df1k["time"] < 3/1000 )]
plt.plot(df1k["time"] * 1000, df1k["inputV"], label="input")
plt.plot(df1k["time"] * 1000, df1k["outputV"], label="output", c="r")

plt.xlabel("Time (ms)")
plt.ylabel("Voltage (V)")
plt.title("PSpice Simulated - Differential Amplifier, Triangle Wave Input 1kHz")
plt.grid()

plt.subplot(2,2,3)
df5k = df5k[(df5k["time"] < 3/5000 )]
plt.plot(df5k["time"] * 1000, df5k["inputV"], label="input")
plt.plot(df5k["time"] * 1000, df5k["outputV"], label="output", c="r")

plt.xlabel("Time (ms)")
plt.ylabel("Voltage (V)")
plt.title("PSpice Simulated - Differential Amplifier, Triangle Wave Input 5kHz")
plt.grid()

plt.subplot(2,2,4)
df10k = df10k[(df10k["time"] < 3/10000 )]
plt.plot(df10k["time"] * 1000, df10k["inputV"], label="input")
plt.plot(df10k["time"] * 1000, df10k["outputV"], label="output", c="r")
#plt.xticks([-1/10000, -0.75/10000, -0.5/10000, -0.25/10000, 0, 0.25/10000, 0.5/10000, 0.75/10000, 1/10000], ["-0.1", "-0.075", "-0.05", "-0.025", "0", "0.025", "0.05", "0.075", "0.1"])

plt.xlabel("Time (ms)")
plt.ylabel("Voltage (V)")
plt.title("PSpice Simulated - Differential Amplifier, Triangle Wave Input 5kHz")
plt.grid()

# %%
df500 = pd.read_csv(".\prelab\intergrator\sine\IntegralSine500.csv", skiprows=24, encoding="latin1")
df500.columns = ["time", "outputV", "inputV"]
df1k = pd.read_csv(".\prelab\intergrator\sine\IntegralSine1k.csv", skiprows=24, encoding="latin1")
df1k.columns = ["time", "outputV", "inputV"]
df5k = pd.read_csv(".\prelab\intergrator\sine\IntegralSine5k.csv", skiprows=19, encoding="latin1")
df5k.columns = ["time", "outputV", "inputV"]
df10k = pd.read_csv(".\prelab\intergrator\sine\IntegralSine10k.csv", skiprows=19, encoding="latin1")
df10k.columns = ["time", "outputV", "inputV"]

differentialSineDataset = [df500, df1k, df5k, df10k]

#Plot all df in differentialSineDataset
#Get the point where the input is 0 and greater than -0015
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
df500 = df500[(df500["time"] < 3/500 )]
plt.plot(df500["time"] * 1000, df500["inputV"], label="input")
plt.plot(df500["time"] * 1000, df500["outputV"], label="output", c="r")

plt.xlabel("Time (ms)")
plt.ylabel("Voltage (V)")
plt.title("PSpice Simulated - Integrator Amplifier, Sine Wave Input 500Hz")
plt.grid()

plt.subplot(2,2,2)
df1k = df1k[(df1k["time"] < 3/1000 )]
plt.plot(df1k["time"] * 1000, df1k["inputV"], label="input")
plt.plot(df1k["time"] * 1000, df1k["outputV"], label="output", c="r")

plt.xlabel("Time (ms)")
plt.ylabel("Voltage (V)")
plt.title("PSpice Simulated - Integrator Amplifier, Sine Wave Input 1kHz")
plt.grid()

plt.subplot(2,2,3)
df5k = df5k[(df5k["time"] < 3/5000 )]
plt.plot(df5k["time"] * 1000, df5k["inputV"], label="input")
plt.plot(df5k["time"] * 1000, df5k["outputV"], label="output", c="r")

plt.xlabel("Time (ms)")
plt.ylabel("Voltage (V)")
plt.title("PSpice Simulated - Integrator Amplifier, Sine Wave Input 5kHz")
plt.grid()

plt.subplot(2,2,4)
df10k = df10k[(df10k["time"] < 3/10000 )]
plt.plot(df10k["time"] * 1000, df10k["inputV"], label="input")
plt.plot(df10k["time"] * 1000, df10k["outputV"], label="output", c="r")

plt.xlabel("Time (ms)")
plt.ylabel("Voltage (V)")
plt.title("PSpice Simulated - Integrator Amplifier, Sine Wave Input 10kHz")
plt.grid()

# %%
df500 = pd.read_csv(".\prelab\intergrator\\triangle\IntegralTriangle500.csv", skiprows=24, encoding="latin1")
df500.columns = ["time", "inputV", "outputV"]
df1k = pd.read_csv(".\prelab\intergrator\\triangle\IntegralTriangle1k.csv", skiprows=24, encoding="latin1")
df1k.columns = ["time", "inputV", "outputV"]
df5k = pd.read_csv(".\prelab\intergrator\\triangle\IntegralTriangle5k.csv", skiprows=24, encoding="latin1")
df5k.columns = ["time", "inputV", "outputV"]
df10k = pd.read_csv(".\prelab\intergrator\\triangle\IntegralTriangle10k.csv", skiprows=24, encoding="latin1")
df10k.columns = ["time", "inputV", "outputV"]

differentialSineDataset = [df500, df1k, df5k, df10k]

#Plot all df in differentialSineDataset
#Get the point where the input is 0 and greater than -0015
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
#df500 = df500[(df500["time"] < 3/500 )]
plt.plot(df500["time"] * 1000, df500["inputV"], label="input")
plt.plot(df500["time"] * 1000, df500["outputV"], label="output", c="r")

plt.xlabel("Time (ms)")
plt.ylabel("Voltage (V)")
plt.title("PSpice Simulated - Integrator Amplifier, Square Wave Input 500Hz")
plt.grid()

plt.subplot(2,2,2)
#df1k = df1k[(df1k["time"] < 3/1000 )]
plt.plot(df1k["time"] * 1000, df1k["inputV"], label="input")
plt.plot(df1k["time"] * 1000, df1k["outputV"], label="output", c="r")

plt.xlabel("Time (ms)")
plt.ylabel("Voltage (V)")
plt.title("PSpice Simulated - Integrator Amplifier, Square Wave Input 1kHz")
plt.grid()

plt.subplot(2,2,3)
df5k = df5k[(df5k["time"] < 3/5000 )]
plt.plot(df5k["time"] * 1000, df5k["inputV"], label="input")
plt.plot(df5k["time"] * 1000, df5k["outputV"], label="output", c="r")

plt.xlabel("Time (ms)")
plt.ylabel("Voltage (V)")
plt.title("PSpice Simulated - Integrator Amplifier, Square Wave Input 5kHz")
plt.grid()

plt.subplot(2,2,4)
df10k = df10k[(df10k["time"] < 3/10000 )]
plt.plot(df10k["time"] * 1000, df10k["inputV"], label="input")
plt.plot(df10k["time"] * 1000, df10k["outputV"], label="output", c="r")

plt.xlabel("Time (ms)")
plt.ylabel("Voltage (V)")
plt.title("PSpice Simulated - Integrator Amplifier, Square Wave Input 10kHz")
plt.grid()

# %%
df = pd.read_csv(".\prelab\wienBridge.csv", skiprows=27, encoding="latin1")
df.columns = ["time", "outputV"]

df = df[(df["time"] < 30/1000)]

plt.plot(df["time"] * 1000, df["outputV"], c="r")
plt.xlabel("Time (ms)")
plt.ylabel("Voltage (V)")
plt.title("PSpice Simulated - Wien Bridge Oscillator Output Voltage")
plt.grid()
